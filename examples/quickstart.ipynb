# %% [markdown]
# # Agentic AI MCP - Quick Start

# %% [markdown]
# ## Step 1: Setup

# %%
## 1. install it if you have not already
# !uv pip install agentic_ai_mcp==0.4.0

import agentic_ai_mcp
print(f"Version: {agentic_ai_mcp.__version__}")
# Out:
# Version: 0.4.0

# %%
## 2. make sure you have valid 'ANTHROPIC_API_KEY' in your .env file

# %% [markdown]
# ## Step 2: Define Functions

# %%
def add(a: int, b: int) -> int:
    """Add two numbers."""
    return a + b

def greet(name: str, times: int = 1) -> str:
    """Greet someone."""
    return ("Hello, " + name + "! ") * times

# %% [markdown]
# ## Step 3: Create AgenticAI, Register Tools, and Run MCP Server

# %%
from agentic_ai_mcp import AgenticAI

ai = AgenticAI(verbose=True)
ai.register_tool(add)
ai.register_tool(greet)
ai.run_mcp_server()
# Out:
#                  ╭──────────────────────────────────────────────────────────────────────────────╮
#                  │                                                                              │
#                  │                                                                              │
#                  │                         ▄▀▀ ▄▀█ █▀▀ ▀█▀ █▀▄▀█ █▀▀ █▀█                        │
#                  │                         █▀  █▀█ ▄▄█  █  █ ▀ █ █▄▄ █▀▀                        │
#                  │                                                                              │
#                  │                                                                              │
#                  │                                FastMCP 3.0.2                                 │
#                  │                            https://gofastmcp.com                             │
#                  │                                                                              │
#                  │                    🖥  Server:      agentic-ai, 3.0.2                         │
#                  │                    🚀 Deploy free: https://fastmcp.cloud                     │
#                  │                                                                              │
#                  ╰──────────────────────────────────────────────────────────────────────────────╯
# [02/25/26 14:03:36] INFO     Starting MCP server 'agentic-ai' with transport 'http' on             ]8;id=46346;file:///mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/fastmcp/server/mixins/transport.py\transport.py]8;;\:]8;id=643156;file:///mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/fastmcp/server/mixins/transport.py#273\273]8;;\
#                              http://127.0.0.1:8888/mcp
# INFO:     Started server process [30980]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 98] error while attempting to bind on address ('127.0.0.1', 8888): [errno 98] address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# MCP Server running at http://127.0.0.1:8888/mcp
# Tools: ['add', 'greet']

# %% [markdown]
# ## Step 4: Execute Agentic Workflow

# %%
result = await ai.run("calculate ((1+2)+(1+1)) and greet 'Tom' the result times")
print(result)
# Out:
# INFO:     127.0.0.1:60190 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60206 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:60220 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60236 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60250 - "DELETE /mcp HTTP/1.1" 200 OK
#
# ==================================================
# PROMPT: calculate ((1+2)+(1+1)) and greet 'Tom' the result times
# ==================================================
# /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/agentic_ai_mcp/agentic.py:193: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   self._agent = create_react_agent(llm, self._langchain_tools)
# INFO:     127.0.0.1:60262 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60274 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60284 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:60296 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60300 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:60302 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60308 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60324 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60340 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60344 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60348 - "DELETE /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60354 - "DELETE /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44920 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44936 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:44946 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44962 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44974 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44982 - "DELETE /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44998 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45014 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:45028 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45044 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45046 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45058 - "DELETE /mcp HTTP/1.1" 200 OK
# STEP 1: add({'a': 1, 'b': 2})
# STEP 2: add({'a': 1, 'b': 1})
#   → CallToolResult(content=[TextContent(type='text', text='3', annotations=None, meta=None)], structured_content={'result': 3}, meta=None, data=3, is_error=False)
#
#   → CallToolResult(content=[TextContent(type='text', text='2', annotations=None, meta=None)], structured_content={'result': 2}, meta=None, data=2, is_error=False)
#
# STEP 3: add({'a': 3, 'b': 2})
#   → CallToolResult(content=[TextContent(type='text', text='5', annotations=None, meta=None)], structured_content={'result': 5}, meta=None, data=5, is_error=False)
#
# STEP 4: greet({'name': 'Tom', 'times': 5})
#   → CallToolResult(content=[TextContent(type='text', text='Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! ', annotations=None, meta=None)], structured_content={'result': 'Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! '}, meta=None, data='Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! ', is_error=False)
#
# ==================================================
# RESULT: Done! The calculation ((1+2)+(1+1)) = 5, and Tom has been greeted 5 times: **Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom!**
# ==================================================
#
# Done! The calculation ((1+2)+(1+1)) = 5, and Tom has been greeted 5 times: **Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom!**
