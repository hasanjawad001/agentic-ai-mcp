# %% [markdown]
# # Agentic AI MCP - Quick Start

# %% [markdown]
# ## Step 1: Setup

# %%
## 1. install it if you have not already
# !uv pip install agentic_ai_mcp==0.4.2

import agentic_ai_mcp
print(f"Version: {agentic_ai_mcp.__version__}")
# Out:
# Version: 0.4.2

# %%
## 2. make sure you have valid 'ANTHROPIC_API_KEY' in your .env file

# %% [markdown]
# ## Step 2: Define Functions

# %%
def add(a: int, b: int) -> int:
    """Add two numbers."""
    return a + b

def greet(name: str, times: int = 1) -> str:
    """Greet someone."""
    return ("Hello, " + name + "! ") * times

# %% [markdown]
# ## Step 3: Create AgenticAI, Register Tools, and Run MCP Server

# %%
from agentic_ai_mcp import AgenticAI

ai = AgenticAI(verbose=True)
ai.register_tool(add)
ai.register_tool(greet)
ai.run_mcp_server()
# Out:
#                  ╭──────────────────────────────────────────────────────────────────────────────╮
#                  │                                                                              │
#                  │                                                                              │
#                  │                         ▄▀▀ ▄▀█ █▀▀ ▀█▀ █▀▄▀█ █▀▀ █▀█                        │
#                  │                         █▀  █▀█ ▄▄█  █  █ ▀ █ █▄▄ █▀▀                        │
#                  │                                                                              │
#                  │                                                                              │
#                  │                                FastMCP 3.0.2                                 │
#                  │                            https://gofastmcp.com                             │
#                  │                                                                              │
#                  │                    🖥  Server:      agentic-ai, 3.0.2                         │
#                  │                    🚀 Deploy free: https://fastmcp.cloud                     │
#                  │                                                                              │
#                  ╰──────────────────────────────────────────────────────────────────────────────╯
# [02/25/26 16:47:05] INFO     Starting MCP server 'agentic-ai' with transport 'http' on             ]8;id=653327;file:///mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/fastmcp/server/mixins/transport.py\transport.py]8;;\:]8;id=185322;file:///mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/fastmcp/server/mixins/transport.py#273\273]8;;\
#                              http://127.0.0.1:8888/mcp
# INFO:     Started server process [41416]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8888 (Press CTRL+C to quit)
# MCP Server running at http://127.0.0.1:8888/mcp
# Tools: ['add', 'greet']

# %% [markdown]
# ## Step 4: Execute Agentic Workflow (Simple Task)

# %%
result = await ai.run("calculate ((1+2)+(1+1)) and greet 'Tom' the result times")
print(result)
# Out:
# INFO:     127.0.0.1:57226 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57228 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:57238 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57244 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57254 - "DELETE /mcp HTTP/1.1" 200 OK
#
# ==================================================
# PROMPT: calculate ((1+2)+(1+1)) and greet 'Tom' the result times
# ==================================================
# /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/agentic-ai-mcp/src/agentic_ai_mcp/agentic.py:213: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   self._agent = create_react_agent(self._get_llm(), self._langchain_tools)
# INFO:     127.0.0.1:34156 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34170 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34186 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:34188 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34196 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:34200 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34206 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34216 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34220 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34222 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34236 - "DELETE /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34248 - "DELETE /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34258 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34260 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:34262 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34274 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34282 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34288 - "DELETE /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34290 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34302 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:34312 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34320 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34324 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34334 - "DELETE /mcp HTTP/1.1" 200 OK
# STEP 1: add({'a': 1, 'b': 2})
# STEP 2: add({'a': 1, 'b': 1})
#   → CallToolResult(content=[TextContent(type='text', text='3', annotations=None, meta=None)], structured_content={'result': 3}, meta=None, data=3, is_error=False)
#
#   → CallToolResult(content=[TextContent(type='text', text='2', annotations=None, meta=None)], structured_content={'result': 2}, meta=None, data=2, is_error=False)
#
# STEP 3: add({'a': 3, 'b': 2})
#   → CallToolResult(content=[TextContent(type='text', text='5', annotations=None, meta=None)], structured_content={'result': 5}, meta=None, data=5, is_error=False)
#
# STEP 4: greet({'name': 'Tom', 'times': 5})
#   → CallToolResult(content=[TextContent(type='text', text='Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! ', annotations=None, meta=None)], structured_content={'result': 'Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! '}, meta=None, data='Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! ', is_error=False)
#
# ==================================================
# RESULT: Done! The calculation ((1+2)+(1+1)) = 5, and I've greeted Tom 5 times:
# **Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom!**
# ==================================================
#
# Done! The calculation ((1+2)+(1+1)) = 5, and I've greeted Tom 5 times:
# **Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom! Hello, Tom!**

# %% [markdown]
# ## Step 5: Execute Agentic Workflow (Complex Task)

# %%
result = await ai.run_with_planning("first calculate 10+20, then greet 'Alice' with the result number of times")
print(result)
# Out:
# ==================================================
# PLANNING MODE
# TASK: first calculate 10+20, then greet 'Alice' with the result number of times
# ==================================================
#
# PLAN:
#   1. add 10 and 20
#   2. greet Alice 30 times
#
# EXECUTING STEP 1/2: add 10 and 20
# ----------------------------------------
# INFO:     127.0.0.1:58006 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58014 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:58024 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58040 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58044 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58058 - "DELETE /mcp HTTP/1.1" 200 OK
#   TOOL CALL 1: add({'a': 10, 'b': 20})
#     → CallToolResult(content=[TextContent(type='text', text='30', annotations=None, meta=None)], structured_content={'result': 30}, meta=None, data=30, is_error=False)
#   AI RESPONSE: The sum of 10 and 20 is **30**.
# ----------------------------------------
# STEP 1 COMPLETE
#
# EXECUTING STEP 2/2: greet Alice 30 times
# ----------------------------------------
# INFO:     127.0.0.1:58060 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58064 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:58076 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58082 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58094 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58100 - "DELETE /mcp HTTP/1.1" 200 OK
#   TOOL CALL 1: greet({'name': 'Alice', 'times': 30})
#     → CallToolResult(content=[TextContent(type='text', text='Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! ', annotations=None, meta=None)], structured_content={'result': 'Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! '}, meta=None, data='Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! Hello, Alice! ', is_error=False)
#   AI RESPONSE: Done! I've greeted Alice 30 times. The greeting function returned "Hello, Alice!" repeated 30 times in succession.
# ----------------------------------------
# STEP 2 COMPLETE
#
# ==================================================
# SYNTHESIZING RESULTS
# ==================================================
# Original task: first calculate 10+20, then greet 'Alice' with the result number of times
#
# Step results collected:
#   • Step 1: The sum of 10 and 20 is **30**.
#   • Step 2: Done! I've greeted Alice 30 times. The greeting function returned "Hello, Alice!" repeated 30 times in succession.
#
# Sending synthesis prompt...
# Synthesis complete.
# ==================================================
#
# ==================================================
# FINAL RESULT: # Final Response
#
# I have successfully completed the multi-step task:
#
# 1. **Calculation**: 10 + 20 = **30**
# 2. **Greeting**: Alice has been greeted **30 times** with "Hello, Alice!"
#
# The task is now complete.
# ==================================================
#
# # Final Response
#
# I have successfully completed the multi-step task:
#
# 1. **Calculation**: 10 + 20 = **30**
# 2. **Greeting**: Alice has been greeted **30 times** with "Hello, Alice!"
#
# The task is now complete.
