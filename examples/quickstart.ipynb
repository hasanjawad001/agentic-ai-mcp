# %% [markdown]
# # Agentic AI MCP - Quick Start

# %% [markdown]
# ## Step 1: Setup

# %%
import os
from dotenv import load_dotenv
import agentic_ai_mcp
from agentic_ai_mcp import AgenticAI

load_dotenv()
if os.getenv("ANTHROPIC_API_KEY"):
    print("API key loaded!")
else:
    print("Set ANTHROPIC_API_KEY in .env file")
print(f"Version: {agentic_ai_mcp.__version__}")
# Out:
# API key loaded!
# Version: 0.4.0

# %% [markdown]
# ## Step 2: Define Functions

# %%
def add(a: int, b: int) -> int:
    """Add two numbers."""
    return a + b

def greet(name: str, times: int = 1) -> str:
    """Greet someone."""
    return ("Hello, " + name + "! ") * times

# %% [markdown]
# ## Step 3: Create AgenticAI & Register Tools

# %%
ai = AgenticAI()
ai.register_tool(add)
ai.register_tool(greet)
ai.run_mcp_server()
# Out:
#                  ╭──────────────────────────────────────────────────────────────────────────────╮
#                  │                                                                              │
#                  │                                                                              │
#                  │                         ▄▀▀ ▄▀█ █▀▀ ▀█▀ █▀▄▀█ █▀▀ █▀█                        │
#                  │                         █▀  █▀█ ▄▄█  █  █ ▀ █ █▄▄ █▀▀                        │
#                  │                                                                              │
#                  │                                                                              │
#                  │                                FastMCP 3.0.2                                 │
#                  │                            https://gofastmcp.com                             │
#                  │                                                                              │
#                  │                    🖥  Server:      agentic-ai, 3.0.2                         │
#                  │                    🚀 Deploy free: https://fastmcp.cloud                     │
#                  │                                                                              │
#                  ╰──────────────────────────────────────────────────────────────────────────────╯
# [02/25/26 09:42:02] INFO     Starting MCP server 'agentic-ai' with transport 'http' on             ]8;id=491346;file:///mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/fastmcp/server/mixins/transport.py\transport.py]8;;\:]8;id=85671;file:///mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/fastmcp/server/mixins/transport.py#273\273]8;;\
#                              http://127.0.0.1:8888/mcp
# INFO:     Started server process [15540]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8888 (Press CTRL+C to quit)
# MCP Server running at http://127.0.0.1:8888/mcp
# Tools: ['add', 'greet']

# %% [markdown]
# ## Step 4: Run

# %%
result = await ai.run("calculate 2+3 and greet 'Tom' the result times")
print(result)
# Out:
# INFO:     127.0.0.1:40266 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40282 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:40296 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40310 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40324 - "DELETE /mcp HTTP/1.1" 200 OK
#
# ==================================================
# PROMPT: calculate 2+3 and greet 'Tom' the result times
# ==================================================
# /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/agentic-ai-mcp/src/agentic_ai_mcp/agentic.py:195: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   self._agent = create_react_agent(llm, self._langchain_tools)
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = await ai.run("calculate 2+3 and greet 'Tom' the result times")
#       2 print(result)
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/agentic-ai-mcp/src/agentic_ai_mcp/agentic.py:203, in AgenticAI.run(self, prompt)
#     200     print(f"{'='*50}\n")
#     202 # Run agent
# --> 203 result = await self._agent.ainvoke({
#     204     "messages": [HumanMessage(content=prompt)]
#     205 })
#     207 # Process and return response
#     208 messages = result.get("messages", [])
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langgraph/pregel/main.py:3161, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3158 chunks: list[dict[str, Any] | Any] = []
#    3159 interrupts: list[Interrupt] = []
# -> 3161 async for chunk in self.astream(
#    3162     input,
#    3163     config,
#    3164     context=context,
#    3165     stream_mode=["updates", "values"]
#    3166     if stream_mode == "values"
#    3167     else stream_mode,
#    3168     print_mode=print_mode,
#    3169     output_keys=output_keys,
#    3170     interrupt_before=interrupt_before,
#    3171     interrupt_after=interrupt_after,
#    3172     durability=durability,
#    3173     **kwargs,
#    3174 ):
#    3175     if stream_mode == "values":
#    3176         if len(chunk) == 2:
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langgraph/pregel/main.py:2974, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2972 for task in await loop.amatch_cached_writes():
#    2973     loop.output_writes(task.id, task.writes, cached=True)
# -> 2974 async for _ in runner.atick(
#    2975     [t for t in loop.tasks.values() if not t.writes],
#    2976     timeout=self.step_timeout,
#    2977     get_waiter=get_waiter,
#    2978     schedule_task=loop.aaccept_push,
#    2979 ):
#    2980     # emit output
#    2981     for o in _output(
#    2982         stream_mode,
#    2983         print_mode,
#    (...)   2986         asyncio.QueueEmpty,
#    2987     ):
#    2988         yield o
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langgraph/pregel/_runner.py:304, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     302 t = tasks[0]
#     303 try:
# --> 304     await arun_with_retry(
#     305         t,
#     306         retry_policy,
#     307         stream=self.use_astream,
#     308         configurable={
#     309             CONFIG_KEY_CALL: partial(
#     310                 _acall,
#     311                 weakref.ref(t),
#     312                 stream=self.use_astream,
#     313                 retry_policy=retry_policy,
#     314                 futures=weakref.ref(futures),
#     315                 schedule_task=schedule_task,
#     316                 submit=self.submit,
#     317                 loop=loop,
#     318             ),
#     319         },
#     320     )
#     321     self.commit(t, None)
#     322 except Exception as exc:
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langgraph/pregel/_retry.py:138, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     136         break
#     137     else:
# --> 138         return await task.proc.ainvoke(task.input, config)
#     139 except ParentCommand as exc:
#     140     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:705, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     703     # run in context
#     704     with set_config_context(config, run) as context:
# --> 705         input = await asyncio.create_task(
#     706             step.ainvoke(input, config, **kwargs), context=context
#     707         )
#     708 else:
#     709     input = await step.ainvoke(input, config, **kwargs)
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:464, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     462         run = None
#     463     with set_config_context(child_config, run) as context:
# --> 464         ret = await asyncio.create_task(coro, context=context)
#     465 else:
#     466     ret = await coro
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langgraph/prebuilt/chat_agent_executor.py:707, in create_react_agent.<locals>.acall_model(state, runtime, config)
#     705     response = cast(AIMessage, await dynamic_model.ainvoke(model_input, config))  # type: ignore[arg-type]
#     706 else:
# --> 707     response = cast(AIMessage, await static_model.ainvoke(model_input, config))  # type: ignore[union-attr]
#     709 # add agent name to the AIMessage
#     710 response.name = name
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_core/runnables/base.py:3197, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    3195             else:
#    3196                 part = functools.partial(step.ainvoke, input_, config)
# -> 3197             input_ = await coro_with_context(part(), context, create_task=True)
#    3198     # finish the root run
#    3199 except BaseException as e:
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_core/runnables/base.py:5708, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5701 @override
#    5702 async def ainvoke(
#    5703     self,
#    (...)   5706     **kwargs: Any | None,
#    5707 ) -> Output:
# -> 5708     return await self.bound.ainvoke(
#    5709         input,
#    5710         self._merge_configs(config),
#    5711         **{**self.kwargs, **kwargs},
#    5712     )
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:425, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     415 @override
#     416 async def ainvoke(
#     417     self,
#    (...)    422     **kwargs: Any,
#     423 ) -> AIMessage:
#     424     config = ensure_config(config)
# --> 425     llm_result = await self.agenerate_prompt(
#     426         [self._convert_input(input)],
#     427         stop=stop,
#     428         callbacks=config.get("callbacks"),
#     429         tags=config.get("tags"),
#     430         metadata=config.get("metadata"),
#     431         run_name=config.get("run_name"),
#     432         run_id=config.pop("run_id", None),
#     433         **kwargs,
#     434     )
#     435     return cast(
#     436         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     437     )
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1134, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1125 @override
#    1126 async def agenerate_prompt(
#    1127     self,
#    (...)   1131     **kwargs: Any,
#    1132 ) -> LLMResult:
#    1133     prompt_messages = [p.to_messages() for p in prompts]
# -> 1134     return await self.agenerate(
#    1135         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1136     )
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1092, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1079     if run_managers:
#    1080         await asyncio.gather(
#    1081             *[
#    1082                 run_manager.on_llm_end(
#    (...)   1090             ]
#    1091         )
# -> 1092     raise exceptions[0]
#    1093 flattened_outputs = [
#    1094     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[union-attr]
#    1095     for res in results
#    1096 ]
#    1097 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1361, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1359     result = generate_from_stream(iter(chunks))
#    1360 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 1361     result = await self._agenerate(
#    1362         messages, stop=stop, run_manager=run_manager, **kwargs
#    1363     )
#    1364 else:
#    1365     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1446, in ChatAnthropic._agenerate(self, messages, stop, run_manager, **kwargs)
#    1444 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1445 try:
# -> 1446     data = await self._acreate(payload)
#    1447 except anthropic.BadRequestError as e:
#    1448     _handle_anthropic_bad_request(e)
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1291, in ChatAnthropic._acreate(self, payload)
#    1289 if "betas" in payload:
#    1290     return await self._async_client.beta.messages.create(**payload)
# -> 1291 return await self._async_client.messages.create(**payload)
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:2443, in AsyncMessages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    2436 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    2437     warnings.warn(
#    2438         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    2439         UserWarning,
#    2440         stacklevel=3,
#    2441     )
# -> 2443 return await self._post(
#    2444     "/v1/messages",
#    2445     body=await async_maybe_transform(
#    2446         {
#    2447             "max_tokens": max_tokens,
#    2448             "messages": messages,
#    2449             "model": model,
#    2450             "cache_control": cache_control,
#    2451             "container": container,
#    2452             "inference_geo": inference_geo,
#    2453             "metadata": metadata,
#    2454             "output_config": output_config,
#    2455             "service_tier": service_tier,
#    2456             "stop_sequences": stop_sequences,
#    2457             "stream": stream,
#    2458             "system": system,
#    2459             "temperature": temperature,
#    2460             "thinking": thinking,
#    2461             "tool_choice": tool_choice,
#    2462             "tools": tools,
#    2463             "top_k": top_k,
#    2464             "top_p": top_p,
#    2465         },
#    2466         message_create_params.MessageCreateParamsStreaming
#    2467         if stream
#    2468         else message_create_params.MessageCreateParamsNonStreaming,
#    2469     ),
#    2470     options=make_request_options(
#    2471         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2472     ),
#    2473     cast_to=Message,
#    2474     stream=stream or False,
#    2475     stream_cls=AsyncStream[RawMessageStreamEvent],
#    2476 )
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/anthropic/_base_client.py:1992, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1983     warnings.warn(
#    1984         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1985         "Please pass raw bytes via the `content` parameter instead.",
#    1986         DeprecationWarning,
#    1987         stacklevel=2,
#    1988     )
#    1989 opts = FinalRequestOptions.construct(
#    1990     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1991 )
# -> 1992 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File /mnt/jawad_cnms_s1/jawad_server/code/20260221_code_agentic_ai/env_caa/lib/python3.13/site-packages/anthropic/_base_client.py:1777, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1774             await err.response.aread()
#    1776         log.debug("Re-raising status error")
# -> 1777         raise self._make_status_error_from_response(err.response) from None
#    1779     break
#    1781 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}, 'request_id': 'req_011CYUxpjx4HANV8LZwKcUzx'}
# During task with name 'agent' and id 'a7fefd81-17b1-5f07-2256-101c0c03c788'
# INFO:     127.0.0.1:58208 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58228 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58214 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:58236 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58242 - "DELETE /mcp HTTP/1.1" 200 OK
